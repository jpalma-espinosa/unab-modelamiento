# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
archivo = './Automobile.csv'
autos = pd.read_csv(archivo, sep=';')

# %%
autos.head(5)
# Out:
#     symboling  normalized-losses Marca fuel-type aspiration num-of-doors  \
# 3           2              164.0  audi       gas        std         four
# 4           2              164.0  audi       gas        std         four
# 6           1              158.0  audi       gas        std         four
# 8           1              158.0  audi       gas      turbo         four
# 10          2              192.0   bmw       gas        std          two
#
#    body-style drive-wheels engine-location  Wheel-base   ...     engine-size  \
# 3       sedan          fwd           front        99.8   ...             109
# 4       sedan          4wd           front        99.4   ...             136
# 6       sedan          fwd           front       105.8   ...             136
# 8       sedan          fwd           front       105.8   ...             131
# 10      sedan          rwd           front       101.2   ...             108
#
# ...

# %%
plt.plot(autos['normalized-losses'])
plt.xlim(0,10)
plt.show()

# %%
autos = autos.dropna(how="any")
autos.head(3)
# Out:
#    symboling  normalized-losses Marca fuel-type aspiration num-of-doors  \
# 3          2              164.0  audi       gas        std         four
# 4          2              164.0  audi       gas        std         four
# 6          1              158.0  audi       gas        std         four
#
#   body-style drive-wheels engine-location  Wheel-base   ...     engine-size  \
# 3      sedan          fwd           front        99.8   ...             109
# 4      sedan          4wd           front        99.4   ...             136
# 6      sedan          fwd           front       105.8   ...             136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 3         mpfi  3.19     3.4              10.0      102.0    5500.0       24
# 4         mpfi  3.19     3.4               8.0      115.0    5500.0       18
# 6         mpfi  3.19     3.4               8.5      110.0    5500.0       19
#
#    highway-mpg   Precio
# 3           30  13950.0
# ...

# %%
autos.describe()
# Out:
#         symboling  normalized-losses  Wheel-base      length       width  \
# count  159.000000         159.000000  159.000000  159.000000  159.000000
# mean     0.735849         121.132075   98.264151  172.413836   65.607547
# std      1.193086          35.651285    5.167416   11.523177    1.947883
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  165.650000   64.000000
# 50%      1.000000         113.000000   96.900000  172.400000   65.400000
# 75%      2.000000         148.000000  100.800000  177.800000   66.500000
# max      3.000000         256.000000  115.600000  202.600000   71.700000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  159.000000   159.000000   159.000000  159.000000  159.000000
# mean    53.899371  2461.138365   119.226415    3.300126    3.236352
# std      2.268761   481.941321    30.460791    0.267336    0.294888
# ...

# %%
# Out:
#            normalized-losses       Marca fuel-type aspiration num-of-doors  \
# symboling
#  2                     164.0        audi       gas        std         four
#  2                     164.0        audi       gas        std         four
#  1                     158.0        audi       gas        std         four
#  1                     158.0        audi       gas      turbo         four
#  2                     192.0         bmw       gas        std          two
#  0                     192.0         bmw       gas        std         four
#  0                     188.0         bmw       gas        std          two
#  0                     188.0         bmw       gas        std         four
#  2                     121.0   chevrolet       gas        std          two
#  1                      98.0   chevrolet       gas        std          two
#  0                      81.0   chevrolet       gas        std         four
# ...

# %%
autos.columns
# Out:
# Index(['normalized-losses', 'Marca', 'fuel-type', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'Wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'Precio'],
#       dtype='object')

# %%
rapidos = autos.sort_values(by='peak-rpm', ascending=False).head(10)

# %%
rapidos.iloc[0]
# Out:
# normalized-losses       168
# Marca                toyota
# fuel-type               gas
# aspiration              std
# num-of-doors            two
# body-style            sedan
# drive-wheels            rwd
# engine-location       front
# Wheel-base             94.5
# length                168.7
# width                    64
# height                 52.6
# curb-weight            2265
# engine-type            dohc
# num-of-cylinders       four
# engine-size              98
# fuel-system            mpfi
# bore                   3.24
# stroke                 3.08
# compression-ratio       9.4
# horsepower              112
# peak-rpm               6600
# city-mpg                 26
# highway-mpg              29
# Precio                 9298
# Name: 1, dtype: object
